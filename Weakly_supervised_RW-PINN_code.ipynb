# %%
#!pip install wiggle
#!pip install tensorflow-addons
#!pip install tensorflow-probability
import scipy.io as sio
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import numpy as np
from random import randint
from sklearn.metrics import mean_squared_error
#from wiggle.wiggle import wiggle
from matplotlib.pyplot import figure
import math
import tensorflow as tf
import tensorflow_probability as tfp
import tensorflow_addons as tfa
import pandas as pd
import sys
import os

# %%
#!pip install pydot

from keras import layers, initializers, optimizers
from keras.layers import Input, Dense, Activation, ZeroPadding1D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling1D, MaxPooling2D, Dropout, GlobalMaxPooling1D, GlobalAveragePooling1D
from keras.layers import LeakyReLU, Reshape
from keras.models import Model, model_from_json, load_model
from keras.preprocessing import image
#from keras.utils import layer_utils, normalize
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
#from keras.utils import plot_model
from keras.utils.vis_utils import plot_model
#from keras.utils import np_utils, normalize
from keras.utils import np_utils
from keras.backend import manual_variable_initialization
from keras.callbacks import EarlyStopping, ModelCheckpoint

# from kt_utils import *

import keras.backend as K
K.set_image_data_format('channels_last')

import sklearn.model_selection
#import pydot

# %%
def ricker_wav(f,n,dt,t0):
    T = dt*(np.floor(n/2))
    t = np.linspace(-T,T,n)
    tau = t-t0
    pi=np.pi
    s = (1-2*tau*tau*f**2*pi**2)*np.exp(-tau**2*pi**2*f**2)
    rw = s
    return rw,t
 
freq=40
dt=7e-4
src_len=np.int(60)
wvlt,tt = ricker_wav(freq,src_len,dt,0)
plt.plot(tt,wvlt)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Source Wavelet")
# Out:
# C:\Users\divakarv\AppData\Local\Temp/ipykernel_10784/3049612121.py:12: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   src_len=np.int(60)
# Text(0.5, 1.0, 'Source Wavelet')

# %%
def SoftSandNew(Kf,RHOf,Phi,Quartz,Clay,Feldspar,Limestone,Dolomite,Pressure,PhiC,Coordination,Fudge):
    # Uncemented sand rock physics model (modified to implement automatic-differentiation)
    #               INPUTS
    #
    #Kf				Fluid bulk modulus
    #RHOB			Fluid density
    #Phi			Porosity (fraction)
    #Quartz, etc.	Volume mineral content in solid phase (fraction)
    #Pressure		Effective pressure (MPa)
    #PhiC			Critical porosity ~0.4
    #Coordination	Coordination number ~6
    #Fudge			Reduction in shear stiffness -- 1 by default
    #
    #a is the contact radius between two spheres at input pressure

    #Balancing mineralogy
    Dolomite=1-(Quartz+Clay+Feldspar+Limestone)
    
    #Constants for clay
    RHOClay=2.65 
    KClay=21 
    GClay=7
    #Solid-phase elastic moduli
    KsV=Quartz*36.6+Clay*KClay+Limestone*76.8+Dolomite*94.9+Feldspar*75.6
    KsR=1/(Quartz/36.6+Clay/KClay+Limestone/76.8+Dolomite/94.9+Feldspar/75.6)
    Ks=0.5*(KsV+KsR)
    
    GsV=Quartz*45+Clay*GClay+Limestone*32+Dolomite*45+Feldspar*25.6
    GsR=1/(Quartz/45+Clay/GClay+Limestone/32+Dolomite/45+Feldspar/25.6)
    Gs=0.5*(GsV+GsR)
    Ms=Ks+(4/3)*Gs
    NUs=0.5*(Ms/Gs-2)/(Ms/Gs-1)
    
    #Solid-phase density
    RHOs=Quartz*2.65+Clay*RHOClay+Limestone*2.71+Dolomite*2.87+Feldspar*2.63
    
    #ILLITE
    #RHOs=2.58; Ms=RHOs.*4.32.*4.32; Gs=RHOs.*2.54.*2.54; NUs=0.5*(Ms./Gs-2)./(Ms./Gs-1); Ks=Ms-(4/3)*Gs;
    
    P=Pressure/1000
    C=Coordination
    
    #================== Dry Rock ====================
    #Effective K and G at PhiC
    #Hertz contact radius (R=1)
    a=tf.pow(((3*3.14*(1-NUs)/(2*C*(1-PhiC)*Gs))*P),(1/3))
    #Normal contact stiffness
    SN=4*a*Gs/(1-NUs)
    #Shear contact stiffness
    ST=8*a*Gs/(2-NUs)
    #Shear contact stiffness FUDGED (reduced)
    ST=ST/Fudge
    
    #Bulk modulus
    Khat=C*(1.-PhiC)*SN/(12*3.14)
    #Shear modulus
    Ghat=C*(1.-PhiC)*(SN+1.5*ST)/(20*3.14)
    
    #Effective bulk and shear moduli at porosity Phi<=PhiC
    KDry1=1/((Phi/PhiC)/(Khat+4*Ghat/3)+((PhiC-Phi)/PhiC)/(Ks+4*Ghat/3))-4*Ghat/3
    ZZ1=(Ghat/6)*(9*Khat+8*Ghat)/(Khat+2*Ghat)
    GDry1=1/((Phi/PhiC)/(Ghat+ZZ1)+((PhiC-Phi)/PhiC)/(Gs+ZZ1))-ZZ1
    MDry1 = KDry1+(4/3)*GDry1
    NuDry1=0.5*(MDry1/GDry1-2)/(MDry1/GDry1-1)
    
    #Effective bulk and shear moduli at porosity Phi>PhiC
    KDry2 = 1/(((1-Phi)/(1-PhiC))/(Khat+4*Ghat/3)+((Phi-PhiC)/(1-PhiC))/(4*Ghat/3))-4*Ghat/3
    ZZ2 = (Ghat/6)*(9*Khat+8*Ghat)/(Khat+2*Ghat)
    GDry2 = 1/(((1-Phi)/(1-PhiC))/(Ghat+ZZ2)+((Phi-PhiC)/(1-PhiC))/(ZZ2))-ZZ2
    MDry2 = KDry2+(4/3)*GDry2
    NuDry2=0.5*(MDry2/GDry2-2)/(MDry2/GDry2-1)
    
    MDry=MDry1*(tf.cast((Phi<=PhiC), tf.float64))+MDry2*(tf.cast((Phi>PhiC), tf.float64)) 
    GDry=GDry1*(tf.cast((Phi<=PhiC), tf.float64))+GDry2*(tf.cast((Phi>PhiC), tf.float64))
    NuDry=NuDry1*(tf.cast((Phi<=PhiC), tf.float64))+NuDry2*(tf.cast((Phi>PhiC), tf.float64))
    KDry=MDry-(4/3)*GDry
    
    # ================== Saturated Rock ============
    KSat=Ks*(Phi*KDry-(1+Phi)*Kf*KDry/Ks+Kf)/((1-Phi)*Kf+Phi*Ks-Kf*KDry/Ks)
    MSat=KSat+(4/3)*GDry
    RHOB=(1-Phi)*RHOs+Phi*RHOf
    Vp=tf.pow((MSat/RHOB),0.5)
    Vs=tf.pow((GDry/RHOB),0.5)
    Ip=Vp*RHOB
    PR=0.5*(MSat/GDry-2)/(MSat/GDry-1)
    
    return Vp,Vs,RHOB

# %%
def RC_fwd_model(vp1,d1,vp2,d2):
    
    Rpp= (vp2*d2-vp1*d1)/(vp2*d2+vp1*d1)
    
    return Rpp

# %%
Kg = 0.06
Kw = 2.61
RHOw = 1.01
RHOg = 0.18 
diffP = 16.5 
RHOs = 2.65
PhiC = 0.4 
Coordination = 14 
Fudge = 1
diffDepth = 1

# We have not analyzed the impact of partialsaturations or the presence of clay on the predictions
vclay=tf.cast(0,tf.float64)
sw=tf.cast(1,tf.float64)

# %%
seis=np.load("seismic_data.npy") ##seismic data
phi_true=np.load("porosity_data.npy") ##porosity data

# %%
phi_max=np.max(phi_true) #can also take 1 or critical porosity (0.4)
phi_min=np.min(phi_true) #can also take 0

# %%
# Normalizing the input and output data  

seis_normalized = (seis - np.min(seis))/(np.max(seis)-np.min(seis))

#seis_compiled=np.concatenate((seis_normalized[:,0,:],seis_normalized[:,1,:]),axis=1)
seis_compiled=seis_normalized

true_output=np.zeros((seis_normalized.shape[0],199))
true_output[:,0:199]=(phi_true-phi_min)/(phi_max-phi_min)

seis_plus_petro_compiled=np.concatenate((seis_compiled,true_output),axis=1)

X_train,X_test,Y_train_unmasked,Y_test_unmasked = sklearn.model_selection.train_test_split(seis_normalized,seis_plus_petro_compiled, test_size=0.2, random_state=1)

X_train_final = np.expand_dims(np.expand_dims(X_train, axis=1),axis=3)
X_test_final = np.expand_dims(np.expand_dims(X_test, axis=1),axis=3)
mask_output_test=Y_test_unmasked[:,0:1]-Y_test_unmasked[:,0:1]
Y_test=np.concatenate((Y_test_unmasked,mask_output_test),axis=1)
mask_output_train=Y_train_unmasked[:,0:1]-Y_train_unmasked[:,0:1]
mask_no=4 ##number of prior known porosity logs
mask_output_train[0:mask_no,:]=1
Y_train=np.concatenate((Y_train_unmasked,mask_output_train),axis=1)

print ("number of training examples = " + str(X_train_final.shape[0]))
print ("number of test examples = " + str(X_test_final.shape[0]))
print ("X_train shape: " + str(X_train_final.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test_final.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 2000
# number of test examples = 500
# X_train shape: (2000, 1, 246, 1)
# Y_train shape: (2000, 446)
# X_test shape: (500, 1, 246, 1)
# Y_test shape: (500, 446)

# %%
## Denominators for normalizing the RMS error in the loss function
denom_phi= tf.reduce_sum(tf.where(Y_train[:,-1] ==1,tf.reduce_mean(Y_train[:,246:246+199],axis=1), Y_train[:,-1]))/mask_no
np.save("denom_phi.npy",denom_phi)

denom_seis= tf.reduce_mean(X_train)
np.save("denom_seis.npy",denom_seis)

# %%
end_time=0.172
time_upscaled = np.arange(0, end_time, dt)

plt.subplot(1,2,1)
plt.plot(np.squeeze(seis[3,:]),time_upscaled)
plt.gca().invert_yaxis()
plt.ylabel('Time(s)')
plt.xlabel('Before normalisation')

plt.subplot(1,2,2)
plt.plot(np.squeeze(seis_normalized[3,:]),time_upscaled)
plt.gca().invert_yaxis()
plt.xlabel('After normalisation')
# Out:
# Text(0.5, 0, 'After normalisation')

# %%
def DecoderLinearInterpLayer(x,xp,fp):
    i = tf.clip_by_value(tf.searchsorted(xp, x, side='right'), 1, xp.shape[1] - 1)

    fp1=tf.gather(fp,indices=i-1, batch_dims=1)
    fp2=tf.gather(fp,indices=i, batch_dims=1)
    xp1=tf.gather(xp,indices=i-1, batch_dims=1)
    xp2=tf.gather(xp,indices=i, batch_dims=1)

    f = (fp1 *  (xp2 - x) + fp2 * (x - xp1)) / (xp2 - xp1)

    left=fp[0,0]
    right = fp[-1,-1]

    ff = tf.where(x < tf.ones_like(x)*tf.expand_dims(xp[:,0],axis=1), left, f)
    fff = tf.where(x > tf.ones_like(x)*tf.expand_dims(xp[:,-1],axis=1), tf.ones_like(x)*tf.expand_dims(fp[:,-1],axis=1), ff)
    return fff

# %%
given_seed = 2

input_final = Input(shape=(X_train_final.shape[1:]))

# Encoder
#1
X = Conv2D(32, (1, 3), strides=(1, 2), name='conv0', padding='same',
           kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros')(input_final)

#X = BatchNormalization(axis=-1, name='bn0')(X)
X = Activation('relu')(X)
#X = Dropout(rate=0.3, name='drop_conv0')(X)

#2
X = Conv2D(64, (1, 7), strides=(1, 2), name='conv1',padding='same',
           kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros')(X)

#X = BatchNormalization(axis=-1, name='bn1')(X)
X = Activation('relu')(X)
#X = Dropout(rate=0.3, name='drop_conv1')(X)

#3
X = Conv2D(128, (1, 15), strides=(1, 2), name='conv2',padding='same',
           kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros')(X)

#X = BatchNormalization(axis=-1, name='bn2')(X)
X = Activation('relu')(X)
#X = Dropout(rate=0.3, name='drop_conv2')(X)

#4 
X = Conv2D(256, (1, 30), strides=(1, 2), name='conv3',padding='same',
           kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros')(X)
          
#X = BatchNormalization(axis=-1, name='bn3')(X)
X = Activation('relu')(X)
X = Dropout(rate=0.3, name='drop_conv3')(X)

# FLATTEN X + FULLYCONNECTED
X = Flatten()(X)
    
X = Dense(199, name='fc0',
          kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros')(X)

encoded = Activation('tanh')(X) ##to scale the output between –1 and 1 before passing it as input to the decoder

# Decoder
encoded=tf.cast(encoded, tf.float64)

phi_for=((encoded + 1)/2) ##scaled between 0 and 1

phi=phi_for * (phi_max - phi_min) + phi_min + 1e-07

depth = np.arange(1,phi.shape[1]+1)*diffDepth

RHOf = sw*RHOw + (1 - sw) * RHOg
Kf = 1/(sw/Kw + (1 - sw)/Kg)

Vp_final,Vs_final,RHO_final=SoftSandNew(Kf,RHOf,phi,(1 - vclay)*0.8,vclay, (1 - vclay)*0.2,0,0,diffP, PhiC, Coordination, Fudge)

#Seismic part

depth_diff = np.mean(np.diff(depth.T))
time0=0.0/(Vp_final[:,0])
time1 = 2*tf.cumsum(depth_diff/(Vp_final*1e3),axis=1)
time_final = tf.concat([tf.expand_dims(time0, axis=1),time1],axis=1)
time = time_final[:,0:-1]

time_new=tf.ones_like(time, dtype=tf.float64)
for i in range(len(time_upscaled)-time.shape[1]):
    time_new=tf.concat([time_new,tf.expand_dims(time0+1.0,axis=1)],axis=1)
pred_t=time_new*time_upscaled

Vp_time=DecoderLinearInterpLayer(pred_t,time,Vp_final)
RHO_time=DecoderLinearInterpLayer(pred_t,time,RHO_final)

Rpp_0=RC_fwd_model(Vp_time[:,0:-1],RHO_time[:,0:-1],Vp_time[:,1:],RHO_time[:,1:])
Rpplast=0.0/(Vp_time[:,0])
Rpp0=tf.concat([Rpp_0,tf.expand_dims(Rpplast, axis=1)],axis=1)

kernel_wvlt = tf.reshape(wvlt, [int(wvlt.shape[0]), 1, 1])
RC0 = tf.expand_dims(Rpp0, axis=2)
seis_for0=tf.squeeze(tf.nn.conv1d(RC0, tf.reverse(kernel_wvlt,[0]), 1,'SAME'),axis=2)
    
seis_for_normalized = (seis_for0 - np.min(seis))/(np.max(seis)-np.min(seis))

seis_for_final = tf.concat([seis_for_normalized,phi_for],axis=1)

# %%
rw_pinn = Model(inputs=input_final, outputs=seis_for_final)
rw_pinn.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1, 246, 1)]  0           []
#
#  conv0 (Conv2D)                 (None, 1, 123, 32)   128         ['input_1[0][0]']
#
#  activation (Activation)        (None, 1, 123, 32)   0           ['conv0[0][0]']
#
#  conv1 (Conv2D)                 (None, 1, 62, 64)    14400       ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 1, 62, 64)    0           ['conv1[0][0]']
#
#  conv2 (Conv2D)                 (None, 1, 31, 128)   123008      ['activation_1[0][0]']
#
#  activation_2 (Activation)      (None, 1, 31, 128)   0           ['conv2[0][0]']
#
#  conv3 (Conv2D)                 (None, 1, 16, 256)   983296      ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 1, 16, 256)   0           ['conv3[0][0]']
#
#  drop_conv3 (Dropout)           (None, 1, 16, 256)   0           ['activation_3[0][0]']
#
#  flatten (Flatten)              (None, 4096)         0           ['drop_conv3[0][0]']
#
#  fc0 (Dense)                    (None, 199)          815303      ['flatten[0][0]']
#
#  activation_4 (Activation)      (None, 199)          0           ['fc0[0][0]']
#
#  tf.cast (TFOpLambda)           (None, 199)          0           ['activation_4[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 199)         0           ['tf.cast[0][0]']
#  da)
#
#  tf.math.truediv (TFOpLambda)   (None, 199)          0           ['tf.__operators__.add[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 199)          0           ['tf.math.truediv[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 199)         0           ['tf.math.multiply[0][0]']
#  mbda)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 199)         0           ['tf.__operators__.add_1[0][0]']
#  mbda)
#
#  tf.math.subtract_2 (TFOpLambda  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#  )
#
#  tf.math.subtract_9 (TFOpLambda  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#  )
#
#  tf.math.subtract_10 (TFOpLambd  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#  a)
#
#  tf.math.subtract (TFOpLambda)  (None, 199)          0           ['tf.__operators__.add_2[0][0]']
#
#  tf.math.truediv_6 (TFOpLambda)  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#
#  tf.math.truediv_8 (TFOpLambda)  (None, 199)         0           ['tf.math.subtract_2[0][0]']
#
#  tf.math.subtract_6 (TFOpLambda  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#  )
#
#  tf.math.subtract_7 (TFOpLambda  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#  )
#
#  tf.math.truediv_19 (TFOpLambda  (None, 199)         0           ['tf.math.subtract_9[0][0]']
#  )
#
#  tf.math.truediv_21 (TFOpLambda  (None, 199)         0           ['tf.math.subtract_10[0][0]']
#  )
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#
#  tf.math.truediv_3 (TFOpLambda)  (None, 199)         0           ['tf.math.subtract[0][0]']
#
#  tf.math.truediv_7 (TFOpLambda)  (None, 199)         0           ['tf.math.truediv_6[0][0]']
#
#  tf.math.truediv_9 (TFOpLambda)  (None, 199)         0           ['tf.math.truediv_8[0][0]']
#
#  tf.math.truediv_14 (TFOpLambda  (None, 199)         0           ['tf.math.subtract_6[0][0]']
#  )
#
#  tf.math.truediv_16 (TFOpLambda  (None, 199)         0           ['tf.math.subtract_7[0][0]']
#  )
#
#  tf.math.truediv_20 (TFOpLambda  (None, 199)         0           ['tf.math.truediv_19[0][0]']
#  )
#
#  tf.math.truediv_22 (TFOpLambda  (None, 199)         0           ['tf.math.truediv_21[0][0]']
#  )
#
#  tf.math.truediv_2 (TFOpLambda)  (None, 199)         0           ['tf.math.truediv_1[0][0]']
#
#  tf.math.truediv_4 (TFOpLambda)  (None, 199)         0           ['tf.math.truediv_3[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 199)         0           ['tf.math.truediv_7[0][0]',
#  mbda)                                                            'tf.math.truediv_9[0][0]']
#
#  tf.math.truediv_15 (TFOpLambda  (None, 199)         0           ['tf.math.truediv_14[0][0]']
#  )
#
#  tf.math.truediv_17 (TFOpLambda  (None, 199)         0           ['tf.math.truediv_16[0][0]']
#  )
#
#  tf.__operators__.add_7 (TFOpLa  (None, 199)         0           ['tf.math.truediv_20[0][0]',
#  mbda)                                                            'tf.math.truediv_22[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 199)         0           ['tf.math.truediv_2[0][0]',
#  mbda)                                                            'tf.math.truediv_4[0][0]']
#
#  tf.math.truediv_10 (TFOpLambda  (None, 199)         0           ['tf.__operators__.add_4[0][0]']
#  )
#
#  tf.__operators__.add_6 (TFOpLa  (None, 199)         0           ['tf.math.truediv_15[0][0]',
#  mbda)                                                            'tf.math.truediv_17[0][0]']
#
#  tf.math.truediv_23 (TFOpLambda  (None, 199)         0           ['tf.__operators__.add_7[0][0]']
#  )
#
#  tf.math.truediv_5 (TFOpLambda)  (None, 199)         0           ['tf.__operators__.add_3[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None, 199)         0           ['tf.math.truediv_10[0][0]']
#  )
#
#  tf.math.truediv_18 (TFOpLambda  (None, 199)         0           ['tf.__operators__.add_6[0][0]']
#  )
#
#  tf.math.subtract_11 (TFOpLambd  (None, 199)         0           ['tf.math.truediv_23[0][0]']
#  a)
#
#  tf.math.less_equal_1 (TFOpLamb  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#  da)
#
#  tf.math.greater_1 (TFOpLambda)  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 199)         0           ['tf.math.truediv_5[0][0]']
#  )
#
#  tf.math.multiply_1 (TFOpLambda  (None, 199)         0           ['tf.math.subtract_3[0][0]']
#  )
#
#  tf.math.less_equal (TFOpLambda  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#  )
#
#  tf.math.subtract_8 (TFOpLambda  (None, 199)         0           ['tf.math.truediv_18[0][0]']
#  )
#
#  tf.math.multiply_3 (TFOpLambda  (None, 199)         0           ['tf.math.subtract_11[0][0]']
#  )
#
#  tf.math.greater (TFOpLambda)   (None, 199)          0           ['tf.__operators__.add_2[0][0]']
#
#  tf.cast_3 (TFOpLambda)         (None, 199)          0           ['tf.math.less_equal_1[0][0]']
#
#  tf.cast_4 (TFOpLambda)         (None, 199)          0           ['tf.math.greater_1[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 199)         0           ['tf.math.subtract_1[0][0]',
#  mbda)                                                            'tf.math.multiply_1[0][0]']
#
#  tf.cast_1 (TFOpLambda)         (None, 199)          0           ['tf.math.less_equal[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 199)         0           ['tf.math.subtract_8[0][0]',
#  mbda)                                                            'tf.math.multiply_3[0][0]']
#
#  tf.cast_2 (TFOpLambda)         (None, 199)          0           ['tf.math.greater[0][0]']
#  tf.math.multiply_7 (TFOpLambda  (None, 199)         0           ['tf.math.subtract_3[0][0]',
#  )                                                                'tf.cast_3[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 199)         0           ['tf.math.subtract_11[0][0]',
#  )                                                                'tf.cast_4[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 199)         0           ['tf.__operators__.add_5[0][0]',
#  )                                                                'tf.cast_1[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, 199)         0           ['tf.__operators__.add_8[0][0]',
#  )                                                                'tf.cast_2[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 199)         0           ['tf.math.multiply_7[0][0]',
#  ambda)                                                           'tf.math.multiply_8[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 199)         0           ['tf.math.multiply_5[0][0]',
#  mbda)                                                            'tf.math.multiply_6[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 199)         0           ['tf.__operators__.add_10[0][0]']
#  a)
#
#  tf.__operators__.add_12 (TFOpL  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#  ambda)
#
#  tf.math.subtract_14 (TFOpLambd  (None, 199)         0           ['tf.__operators__.add_9[0][0]',
#  a)                                                               'tf.math.multiply_11[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None, 199)         0           ['tf.__operators__.add_12[0][0]']
#  a)
#
#  tf.math.multiply_14 (TFOpLambd  (None, 199)         0           ['tf.math.multiply_13[0][0]',
#  a)                                                               'tf.math.subtract_14[0][0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, 199)         0           ['tf.__operators__.add_2[0][0]',
#  a)                                                               'tf.math.subtract_14[0][0]']
#
#  tf.math.truediv_27 (TFOpLambda  (None, 199)         0           ['tf.math.multiply_14[0][0]']
#  )
#
#  tf.math.subtract_16 (TFOpLambd  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#  a)
#
#  tf.math.subtract_15 (TFOpLambd  (None, 199)         0           ['tf.math.multiply_12[0][0]',
#  a)                                                               'tf.math.truediv_27[0][0]']
#
#  tf.math.multiply_16 (TFOpLambd  (None, 199)         0           ['tf.math.subtract_16[0][0]']
#  a)
#
#  tf.math.multiply_17 (TFOpLambd  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#  a)
#
#  tf.math.multiply_18 (TFOpLambd  (None, 199)         0           ['tf.math.subtract_14[0][0]']
#  a)
#
#  tf.__operators__.add_13 (TFOpL  (None, 199)         0           ['tf.math.subtract_15[0][0]']
#  ambda)
#
#  tf.__operators__.add_14 (TFOpL  (None, 199)         0           ['tf.math.multiply_16[0][0]',
#  ambda)                                                           'tf.math.multiply_17[0][0]']
#
#  tf.math.truediv_28 (TFOpLambda  (None, 199)         0           ['tf.math.multiply_18[0][0]']
#  )
#
#  tf.math.multiply_15 (TFOpLambd  (None, 199)         0           ['tf.__operators__.add_13[0][0]']
#  a)
#
#  tf.math.subtract_17 (TFOpLambd  (None, 199)         0           ['tf.__operators__.add_14[0][0]',
#  a)                                                               'tf.math.truediv_28[0][0]']
#
#  tf.math.subtract_18 (TFOpLambd  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#  a)
#
#  tf.math.truediv_29 (TFOpLambda  (None, 199)         0           ['tf.math.multiply_15[0][0]',
#  )                                                                'tf.math.subtract_17[0][0]']
#
#  tf.math.multiply_19 (TFOpLambd  (None, 199)         0           ['tf.__operators__.add_10[0][0]']
#  a)
#
#  tf.math.multiply_20 (TFOpLambd  (None, 199)         0           ['tf.math.subtract_18[0][0]']
#  a)
#
#  tf.math.multiply_21 (TFOpLambd  (None, 199)         0           ['tf.__operators__.add_2[0][0]']
#  a)
#
#  tf.__operators__.add_15 (TFOpL  (None, 199)         0           ['tf.math.truediv_29[0][0]',
#  ambda)                                                           'tf.math.multiply_19[0][0]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 199)         0           ['tf.math.multiply_20[0][0]',
#  ambda)                                                           'tf.math.multiply_21[0][0]']
#
#  tf.math.truediv_30 (TFOpLambda  (None, 199)         0           ['tf.__operators__.add_15[0][0]',
#  )                                                                'tf.__operators__.add_16[0][0]']
#
#  tf.math.pow (TFOpLambda)       (None, 199)          0           ['tf.math.truediv_30[0][0]']
#
#  tf.math.multiply_24 (TFOpLambd  (None, 199)         0           ['tf.math.pow[0][0]']
#  a)
#
#  tf.__operators__.getitem (Slic  (None,)             0           ['tf.math.pow[0][0]']
#  ingOpLambda)
#
#  tf.math.truediv_36 (TFOpLambda  (None, 199)         0           ['tf.math.multiply_24[0][0]']
#  )
#
#  tf.math.truediv_35 (TFOpLambda  (None,)             0           ['tf.__operators__.getitem[0][0]'
#  )                                                               ]
#
#  tf.math.cumsum (TFOpLambda)    (None, 199)          0           ['tf.math.truediv_36[0][0]']
#
#  tf.expand_dims (TFOpLambda)    (None, 1)            0           ['tf.math.truediv_35[0][0]']
#
#  tf.math.multiply_25 (TFOpLambd  (None, 199)         0           ['tf.math.cumsum[0][0]']
#  a)
#
#  tf.concat (TFOpLambda)         (None, 200)          0           ['tf.expand_dims[0][0]',
#                                                                   'tf.math.multiply_25[0][0]']
#
#  tf.__operators__.getitem_1 (Sl  (None, 199)         0           ['tf.concat[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.add_17 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.ones_like (TFOpLambda)      (None, 199)          0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1)            0           ['tf.__operators__.add_17[0][0]']
#
#  tf.__operators__.add_18 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_1 (TFOpLambda)       (None, 200)          0           ['tf.ones_like[0][0]',
#                                                                   'tf.expand_dims_1[0][0]']
#
#  tf.expand_dims_2 (TFOpLambda)  (None, 1)            0           ['tf.__operators__.add_18[0][0]']
#
#  tf.__operators__.add_19 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_2 (TFOpLambda)       (None, 201)          0           ['tf.concat_1[0][0]',
#                                                                   'tf.expand_dims_2[0][0]']
#
#  tf.expand_dims_3 (TFOpLambda)  (None, 1)            0           ['tf.__operators__.add_19[0][0]']
#
#  tf.__operators__.add_20 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_3 (TFOpLambda)       (None, 202)          0           ['tf.concat_2[0][0]',
#                                                                   'tf.expand_dims_3[0][0]']
#
#  tf.expand_dims_4 (TFOpLambda)  (None, 1)            0           ['tf.__operators__.add_20[0][0]']
#
#  tf.__operators__.add_21 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_4 (TFOpLambda)       (None, 203)          0           ['tf.concat_3[0][0]',
#                                                                   'tf.expand_dims_4[0][0]']
#
#  tf.expand_dims_5 (TFOpLambda)  (None, 1)            0           ['tf.__operators__.add_21[0][0]']
#
#  tf.__operators__.add_22 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_5 (TFOpLambda)       (None, 204)          0           ['tf.concat_4[0][0]',
#                                                                   'tf.expand_dims_5[0][0]']
#  tf.expand_dims_6 (TFOpLambda)  (None, 1)            0           ['tf.__operators__.add_22[0][0]']
#
#  tf.__operators__.add_23 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_6 (TFOpLambda)       (None, 205)          0           ['tf.concat_5[0][0]',
#                                                                   'tf.expand_dims_6[0][0]']
#
#  tf.expand_dims_7 (TFOpLambda)  (None, 1)            0           ['tf.__operators__.add_23[0][0]']
#
#  tf.__operators__.add_24 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_7 (TFOpLambda)       (None, 206)          0           ['tf.concat_6[0][0]',
#                                                                   'tf.expand_dims_7[0][0]']
#
#  tf.expand_dims_8 (TFOpLambda)  (None, 1)            0           ['tf.__operators__.add_24[0][0]']
#
#  tf.__operators__.add_25 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_8 (TFOpLambda)       (None, 207)          0           ['tf.concat_7[0][0]',
#                                                                   'tf.expand_dims_8[0][0]']
#
#  tf.expand_dims_9 (TFOpLambda)  (None, 1)            0           ['tf.__operators__.add_25[0][0]']
#
#  tf.__operators__.add_26 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_9 (TFOpLambda)       (None, 208)          0           ['tf.concat_8[0][0]',
#                                                                   'tf.expand_dims_9[0][0]']
#
#  tf.expand_dims_10 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_26[0][0]']
#
#  tf.__operators__.add_27 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_10 (TFOpLambda)      (None, 209)          0           ['tf.concat_9[0][0]',
#                                                                   'tf.expand_dims_10[0][0]']
#
#  tf.expand_dims_11 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_27[0][0]']
#
#  tf.__operators__.add_28 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_11 (TFOpLambda)      (None, 210)          0           ['tf.concat_10[0][0]',
#                                                                   'tf.expand_dims_11[0][0]']
#
#  tf.expand_dims_12 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_28[0][0]']
#
#  tf.__operators__.add_29 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_12 (TFOpLambda)      (None, 211)          0           ['tf.concat_11[0][0]',
#                                                                   'tf.expand_dims_12[0][0]']
#
#  tf.expand_dims_13 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_29[0][0]']
#
#  tf.__operators__.add_30 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_13 (TFOpLambda)      (None, 212)          0           ['tf.concat_12[0][0]',
#                                                                   'tf.expand_dims_13[0][0]']
#
#  tf.expand_dims_14 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_30[0][0]']
#
#  tf.__operators__.add_31 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_14 (TFOpLambda)      (None, 213)          0           ['tf.concat_13[0][0]',
#                                                                   'tf.expand_dims_14[0][0]']
#
#  tf.expand_dims_15 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_31[0][0]']
#
#  tf.__operators__.add_32 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_15 (TFOpLambda)      (None, 214)          0           ['tf.concat_14[0][0]',
#                                                                   'tf.expand_dims_15[0][0]']
#
#  tf.expand_dims_16 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_32[0][0]']
#
#  tf.__operators__.add_33 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_16 (TFOpLambda)      (None, 215)          0           ['tf.concat_15[0][0]',
#                                                                   'tf.expand_dims_16[0][0]']
#
#  tf.expand_dims_17 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_33[0][0]']
#
#  tf.__operators__.add_34 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_17 (TFOpLambda)      (None, 216)          0           ['tf.concat_16[0][0]',
#                                                                   'tf.expand_dims_17[0][0]']
#
#  tf.expand_dims_18 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_34[0][0]']
#
#  tf.__operators__.add_35 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_18 (TFOpLambda)      (None, 217)          0           ['tf.concat_17[0][0]',
#                                                                   'tf.expand_dims_18[0][0]']
#
#  tf.expand_dims_19 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_35[0][0]']
#
#  tf.__operators__.add_36 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_19 (TFOpLambda)      (None, 218)          0           ['tf.concat_18[0][0]',
#                                                                   'tf.expand_dims_19[0][0]']
#
#  tf.expand_dims_20 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_36[0][0]']
#
#  tf.__operators__.add_37 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_20 (TFOpLambda)      (None, 219)          0           ['tf.concat_19[0][0]',
#                                                                   'tf.expand_dims_20[0][0]']
#
#  tf.expand_dims_21 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_37[0][0]']
#
#  tf.__operators__.add_38 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_21 (TFOpLambda)      (None, 220)          0           ['tf.concat_20[0][0]',
#                                                                   'tf.expand_dims_21[0][0]']
#
#  tf.expand_dims_22 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_38[0][0]']
#
#  tf.__operators__.add_39 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_22 (TFOpLambda)      (None, 221)          0           ['tf.concat_21[0][0]',
#                                                                   'tf.expand_dims_22[0][0]']
#
#  tf.expand_dims_23 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_39[0][0]']
#
#  tf.__operators__.add_40 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_23 (TFOpLambda)      (None, 222)          0           ['tf.concat_22[0][0]',
#                                                                   'tf.expand_dims_23[0][0]']
#
#  tf.expand_dims_24 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_40[0][0]']
#
#  tf.__operators__.add_41 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
#  ambda)
#
#  tf.concat_24 (TFOpLambda)      (None, 223)          0           ['tf.concat_23[0][0]',
#                                                                   'tf.expand_dims_24[0][0]']
#
#  tf.expand_dims_25 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.add_41[0][0]']
#
#  tf.__operators__.add_42 (TFOpL  (None,)             0           ['tf.math.truediv_35[0][0]']
# ...
#  a)                                                               'tf.expand_dims_48[0][0]']
#
#  tf.__operators__.add_64 (TFOpL  (None, 246)         0           ['tf.math.multiply_27[0][0]',
#  ambda)                                                           'tf.math.multiply_28[0][0]']
#
#  tf.math.subtract_25 (TFOpLambd  (None, 246)         0           ['tf.compat.v1.gather_3[0][0]',
#  a)                                                               'tf.compat.v1.gather_2[0][0]']
#
#  tf.ones_like_5 (TFOpLambda)    (None, 246)          0           ['tf.math.multiply_26[0][0]']
#
#  tf.expand_dims_52 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.getitem_10[0][
#                                                                  0]']
#
#  tf.__operators__.getitem_11 (S  (None,)             0           ['tf.__operators__.add_16[0][0]']
#  licingOpLambda)
#
#  tf.math.multiply_34 (TFOpLambd  (None, 246)         0           ['tf.ones_like_4[0][0]',
#  a)                                                               'tf.expand_dims_51[0][0]']
#
#  tf.__operators__.add_65 (TFOpL  (None, 246)         0           ['tf.math.multiply_32[0][0]',
#  ambda)                                                           'tf.math.multiply_33[0][0]']
#
#  tf.math.subtract_30 (TFOpLambd  (None, 246)         0           ['tf.compat.v1.gather_7[0][0]',
#  a)                                                               'tf.compat.v1.gather_6[0][0]']
#
#  tf.math.multiply_30 (TFOpLambd  (None, 246)         0           ['tf.ones_like_2[0][0]',
#  a)                                                               'tf.expand_dims_49[0][0]']
#
#  tf.ones_like_3 (TFOpLambda)    (None, 246)          0           ['tf.math.multiply_26[0][0]']
#
#  tf.expand_dims_50 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.getitem_6[0][0
#                                                                  ]']
#
#  tf.math.less (TFOpLambda)      (None, 246)          0           ['tf.math.multiply_26[0][0]',
#                                                                   'tf.math.multiply_29[0][0]']
#
#  tf.__operators__.getitem_2 (Sl  ()                  0           ['tf.math.pow[0][0]']
#  icingOpLambda)
#
#  tf.math.truediv_37 (TFOpLambda  (None, 246)         0           ['tf.__operators__.add_64[0][0]',
#  )                                                                'tf.math.subtract_25[0][0]']
#
#  tf.math.multiply_35 (TFOpLambd  (None, 246)         0           ['tf.ones_like_5[0][0]',
#  a)                                                               'tf.expand_dims_52[0][0]']
#
#  tf.ones_like_6 (TFOpLambda)    (None, 246)          0           ['tf.math.multiply_26[0][0]']
#
#  tf.expand_dims_53 (TFOpLambda)  (None, 1)           0           ['tf.__operators__.getitem_11[0][
#                                                                  0]']
#
#  tf.math.less_1 (TFOpLambda)    (None, 246)          0           ['tf.math.multiply_26[0][0]',
#                                                                   'tf.math.multiply_34[0][0]']
#
#  tf.__operators__.getitem_7 (Sl  ()                  0           ['tf.__operators__.add_16[0][0]']
#  icingOpLambda)
#
#  tf.math.truediv_38 (TFOpLambda  (None, 246)         0           ['tf.__operators__.add_65[0][0]',
#  )                                                                'tf.math.subtract_30[0][0]']
#
#  tf.math.greater_3 (TFOpLambda)  (None, 246)         0           ['tf.math.multiply_26[0][0]',
#                                                                   'tf.math.multiply_30[0][0]']
#
#  tf.math.multiply_31 (TFOpLambd  (None, 246)         0           ['tf.ones_like_3[0][0]',
#  a)                                                               'tf.expand_dims_50[0][0]']
#
#  tf.where (TFOpLambda)          (None, 246)          0           ['tf.math.less[0][0]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]',
#                                                                   'tf.math.truediv_37[0][0]']
#
#  tf.math.greater_4 (TFOpLambda)  (None, 246)         0           ['tf.math.multiply_26[0][0]',
#                                                                   'tf.math.multiply_35[0][0]']
#
#  tf.math.multiply_36 (TFOpLambd  (None, 246)         0           ['tf.ones_like_6[0][0]',
#  a)                                                               'tf.expand_dims_53[0][0]']
#
#  tf.where_2 (TFOpLambda)        (None, 246)          0           ['tf.math.less_1[0][0]',
#                                                                   'tf.__operators__.getitem_7[0][0
#                                                                  ]',
#                                                                   'tf.math.truediv_38[0][0]']
#
#  tf.where_1 (TFOpLambda)        (None, 246)          0           ['tf.math.greater_3[0][0]',
#                                                                   'tf.math.multiply_31[0][0]',
#                                                                   'tf.where[0][0]']
#
#  tf.where_3 (TFOpLambda)        (None, 246)          0           ['tf.math.greater_4[0][0]',
#                                                                   'tf.math.multiply_36[0][0]',
#                                                                   'tf.where_2[0][0]']
#
#  tf.__operators__.getitem_14 (S  (None, 245)         0           ['tf.where_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_15 (S  (None, 245)         0           ['tf.where_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_12 (S  (None, 245)         0           ['tf.where_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_13 (S  (None, 245)         0           ['tf.where_3[0][0]']
#  licingOpLambda)
#
#  tf.math.multiply_37 (TFOpLambd  (None, 245)         0           ['tf.__operators__.getitem_14[0][
#  a)                                                              0]',
#                                                                   'tf.__operators__.getitem_15[0][
#                                                                  0]']
#
#  tf.math.multiply_38 (TFOpLambd  (None, 245)         0           ['tf.__operators__.getitem_12[0][
#  a)                                                              0]',
#                                                                   'tf.__operators__.getitem_13[0][
#                                                                  0]']
#
#  tf.math.multiply_39 (TFOpLambd  (None, 245)         0           ['tf.__operators__.getitem_14[0][
#  a)                                                              0]',
#                                                                   'tf.__operators__.getitem_15[0][
#                                                                  0]']
#
#  tf.math.multiply_40 (TFOpLambd  (None, 245)         0           ['tf.__operators__.getitem_12[0][
#  a)                                                              0]',
#                                                                   'tf.__operators__.getitem_13[0][
#                                                                  0]']
#
#  tf.__operators__.getitem_16 (S  (None,)             0           ['tf.where_1[0][0]']
#  licingOpLambda)
#
#  tf.math.subtract_31 (TFOpLambd  (None, 245)         0           ['tf.math.multiply_37[0][0]',
#  a)                                                               'tf.math.multiply_38[0][0]']
#
#  tf.__operators__.add_66 (TFOpL  (None, 245)         0           ['tf.math.multiply_39[0][0]',
#  ambda)                                                           'tf.math.multiply_40[0][0]']
#
#  tf.math.truediv_40 (TFOpLambda  (None,)             0           ['tf.__operators__.getitem_16[0][
#  )                                                               0]']
#
#  tf.math.truediv_39 (TFOpLambda  (None, 245)         0           ['tf.math.subtract_31[0][0]',
#  )                                                                'tf.__operators__.add_66[0][0]']
#
#  tf.expand_dims_54 (TFOpLambda)  (None, 1)           0           ['tf.math.truediv_40[0][0]']
#
#  tf.concat_48 (TFOpLambda)      (None, 246)          0           ['tf.math.truediv_39[0][0]',
#                                                                   'tf.expand_dims_54[0][0]']
#
#  tf.expand_dims_55 (TFOpLambda)  (None, 246, 1)      0           ['tf.concat_48[0][0]']
#
#  tf.compat.v1.nn.conv1d (TFOpLa  (None, 246, 1)      0           ['tf.expand_dims_55[0][0]']
#  mbda)
#
#  tf.compat.v1.squeeze (TFOpLamb  (None, 246)         0           ['tf.compat.v1.nn.conv1d[0][0]']
#  da)
#
#  tf.math.subtract_32 (TFOpLambd  (None, 246)         0           ['tf.compat.v1.squeeze[0][0]']
#  a)
#
#  tf.math.truediv_41 (TFOpLambda  (None, 246)         0           ['tf.math.subtract_32[0][0]']
#  )
#
#  tf.concat_49 (TFOpLambda)      (None, 445)          0           ['tf.math.truediv_41[0][0]',
#                                                                   'tf.math.truediv[0][0]']
#
# ==================================================================================================
# Total params: 1,936,135
# Trainable params: 1,936,135
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class loss_func(tf.keras.losses.Loss):
    def __init__(self):
        super().__init__()
    def call(self, y_true, y_pred):
        mse_seis1 = tf.reduce_mean(tf.square(y_pred[:,0:246]-y_true[:,0:246]))
        denom_seis= np.load("denom_seis.npy")
        nrmse_seis1 = tf.math.sqrt(mse_seis1)/denom_seis 
        
        rmse_phi = tf.where(y_true[:,-1] ==1, tf.math.sqrt(tf.reduce_mean(tf.square(y_pred[:,246:246+199]-y_true[:,246:246+199]),axis=1)), y_true[:,-1])
        denom_phi= np.load("denom_phi.npy")
        nrmse_phi= tf.reduce_sum(rmse_phi)/denom_phi
        
        return nrmse_seis1+0.1*(nrmse_phi)

# %%
adam =tf.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False)
rw_pinn.compile(loss=loss_func(), optimizer = adam)

# %%
#import os
os.remove("rwpinn_model.h5")

# %%
# Using early stopping and Model Checkpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('rwpinn_model.h5', monitor='val_loss', mode='min', verbose=1, save_weights_only=True)

# %%
# Start the training

Batch_size=128
history = rw_pinn.fit(X_train_final, Y_train, validation_split=0.2, 
                         epochs=200, batch_size=Batch_size, callbacks=[es, mc],
                        verbose = 1)
# Out:
# Epoch 1/200
# 13/13 [==============================] - ETA: 0s - loss: 0.2784
# Epoch 1: saving model to rwpinn_model.h5
# 13/13 [==============================] - 7s 188ms/step - loss: 0.2784 - val_loss: 0.1821
# Epoch 2/200
# 13/13 [==============================] - ETA: 0s - loss: 0.1925
# Epoch 2: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 145ms/step - loss: 0.1925 - val_loss: 0.1228
# Epoch 3/200
# 13/13 [==============================] - ETA: 0s - loss: 0.1441
# Epoch 3: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 152ms/step - loss: 0.1441 - val_loss: 0.0958
# Epoch 4/200
# 13/13 [==============================] - ETA: 0s - loss: 0.1200
# Epoch 4: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 154ms/step - loss: 0.1200 - val_loss: 0.0796
# Epoch 5/200
# 13/13 [==============================] - ETA: 0s - loss: 0.1060
# Epoch 5: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.1060 - val_loss: 0.0697
# Epoch 6/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0966
# Epoch 6: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0966 - val_loss: 0.0628
# Epoch 7/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0876
# Epoch 7: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0876 - val_loss: 0.0579
# Epoch 8/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0851
# Epoch 8: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0851 - val_loss: 0.0545
# Epoch 9/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0802
# Epoch 9: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0802 - val_loss: 0.0513
# Epoch 10/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0773
# Epoch 10: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0773 - val_loss: 0.0485
# Epoch 11/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0739
# Epoch 11: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0739 - val_loss: 0.0465
# Epoch 12/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0708
# Epoch 12: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0708 - val_loss: 0.0442
# Epoch 13/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0692
# Epoch 13: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 146ms/step - loss: 0.0692 - val_loss: 0.0436
# Epoch 14/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0666
# Epoch 14: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 148ms/step - loss: 0.0666 - val_loss: 0.0415
# Epoch 15/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0651
# Epoch 15: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 150ms/step - loss: 0.0651 - val_loss: 0.0406
# Epoch 16/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0630
# Epoch 16: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 149ms/step - loss: 0.0630 - val_loss: 0.0393
# Epoch 17/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0592
# Epoch 17: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 147ms/step - loss: 0.0592 - val_loss: 0.0380
# Epoch 18/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0600
# Epoch 18: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 145ms/step - loss: 0.0600 - val_loss: 0.0374
# Epoch 19/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0587
# Epoch 19: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 146ms/step - loss: 0.0587 - val_loss: 0.0365
# Epoch 20/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0577
# Epoch 20: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 148ms/step - loss: 0.0577 - val_loss: 0.0365
# Epoch 21/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0572
# Epoch 21: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 152ms/step - loss: 0.0572 - val_loss: 0.0353
# Epoch 22/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0543
# Epoch 22: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0543 - val_loss: 0.0350
# Epoch 23/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0544
# Epoch 23: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0544 - val_loss: 0.0337
# Epoch 24/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0537
# Epoch 24: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0537 - val_loss: 0.0333
# Epoch 25/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0517
# Epoch 25: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0517 - val_loss: 0.0327
# Epoch 26/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0522
# Epoch 26: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0522 - val_loss: 0.0323
# Epoch 27/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0513
# Epoch 27: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0513 - val_loss: 0.0327
# Epoch 28/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0498
# Epoch 28: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0498 - val_loss: 0.0313
# Epoch 29/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0496
# Epoch 29: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0496 - val_loss: 0.0308
# Epoch 30/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0491
# Epoch 30: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0491 - val_loss: 0.0316
# Epoch 31/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0490
# Epoch 31: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0490 - val_loss: 0.0302
# Epoch 32/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0478
# Epoch 32: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0478 - val_loss: 0.0305
# Epoch 33/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0477
# Epoch 33: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0477 - val_loss: 0.0301
# Epoch 34/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0461
# Epoch 34: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0461 - val_loss: 0.0306
# Epoch 35/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0447
# Epoch 35: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0447 - val_loss: 0.0290
# Epoch 36/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0455
# Epoch 36: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0455 - val_loss: 0.0286
# Epoch 37/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0452
# Epoch 37: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0452 - val_loss: 0.0287
# Epoch 38/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0446
# Epoch 38: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0446 - val_loss: 0.0286
# Epoch 39/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0453
# Epoch 39: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0453 - val_loss: 0.0286
# Epoch 40/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0446
# Epoch 40: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0446 - val_loss: 0.0284
# Epoch 41/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0439
# Epoch 41: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0439 - val_loss: 0.0275
# Epoch 42/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0433
# Epoch 42: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0433 - val_loss: 0.0277
# Epoch 43/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0428
# Epoch 43: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0428 - val_loss: 0.0270
# Epoch 44/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0422
# Epoch 44: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0422 - val_loss: 0.0266
# Epoch 45/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0422
# Epoch 45: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0422 - val_loss: 0.0271
# Epoch 46/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0417
# Epoch 46: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0417 - val_loss: 0.0280
# Epoch 47/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0417
# Epoch 47: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0417 - val_loss: 0.0269
# Epoch 48/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0412
# Epoch 48: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0412 - val_loss: 0.0261
# Epoch 49/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0399
# Epoch 49: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0399 - val_loss: 0.0263
# Epoch 50/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0400
# Epoch 50: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0400 - val_loss: 0.0255
# Epoch 51/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0405
# Epoch 51: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0405 - val_loss: 0.0261
# Epoch 52/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0404
# Epoch 52: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0404 - val_loss: 0.0263
# Epoch 53/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0399
# Epoch 53: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0399 - val_loss: 0.0256
# Epoch 54/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0389
# Epoch 54: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0389 - val_loss: 0.0252
# Epoch 55/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0388
# Epoch 55: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0388 - val_loss: 0.0257
# Epoch 56/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0394
# Epoch 56: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0394 - val_loss: 0.0251
# Epoch 57/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0383
# Epoch 57: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 147ms/step - loss: 0.0383 - val_loss: 0.0247
# Epoch 58/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0380
# Epoch 58: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0380 - val_loss: 0.0246
# Epoch 59/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0385
# Epoch 59: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 144ms/step - loss: 0.0385 - val_loss: 0.0245
# Epoch 60/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0375
# Epoch 60: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0375 - val_loss: 0.0249
# Epoch 61/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0375
# Epoch 61: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0375 - val_loss: 0.0242
# Epoch 62/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0373
# Epoch 62: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0373 - val_loss: 0.0244
# Epoch 63/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0371
# Epoch 63: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 146ms/step - loss: 0.0371 - val_loss: 0.0241
# Epoch 64/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0368
# Epoch 64: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0368 - val_loss: 0.0252
# Epoch 65/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0375
# Epoch 65: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0375 - val_loss: 0.0246
# Epoch 66/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0369
# Epoch 66: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0369 - val_loss: 0.0264
# Epoch 67/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0373
# Epoch 67: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0373 - val_loss: 0.0243
# Epoch 68/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0369
# Epoch 68: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0369 - val_loss: 0.0244
# Epoch 69/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0363
# Epoch 69: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0363 - val_loss: 0.0234
# Epoch 70/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0361
# Epoch 70: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 147ms/step - loss: 0.0361 - val_loss: 0.0243
# Epoch 71/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0368
# Epoch 71: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 148ms/step - loss: 0.0368 - val_loss: 0.0264
# Epoch 72/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0365
# Epoch 72: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 149ms/step - loss: 0.0365 - val_loss: 0.0243
# Epoch 73/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0355
# Epoch 73: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 145ms/step - loss: 0.0355 - val_loss: 0.0232
# Epoch 74/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0351
# Epoch 74: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0351 - val_loss: 0.0229
# Epoch 75/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0351
# Epoch 75: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0351 - val_loss: 0.0232
# Epoch 76/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0349
# Epoch 76: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0349 - val_loss: 0.0229
# Epoch 77/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0349
# Epoch 77: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0349 - val_loss: 0.0232
# Epoch 78/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0352
# Epoch 78: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0352 - val_loss: 0.0229
# Epoch 79/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0347
# Epoch 79: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0347 - val_loss: 0.0224
# Epoch 80/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0328
# Epoch 80: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0328 - val_loss: 0.0222
# Epoch 81/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0342
# Epoch 81: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0342 - val_loss: 0.0225
# Epoch 82/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0325
# Epoch 82: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0325 - val_loss: 0.0221
# Epoch 83/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0340
# Epoch 83: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 144ms/step - loss: 0.0340 - val_loss: 0.0232
# Epoch 84/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0340
# Epoch 84: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0340 - val_loss: 0.0222
# Epoch 85/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0333
# Epoch 85: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0333 - val_loss: 0.0222
# Epoch 86/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0337
# Epoch 86: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0337 - val_loss: 0.0224
# Epoch 87/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0335
# Epoch 87: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0335 - val_loss: 0.0237
# Epoch 88/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0337
# Epoch 88: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 146ms/step - loss: 0.0337 - val_loss: 0.0222
# Epoch 89/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0333
# Epoch 89: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 147ms/step - loss: 0.0333 - val_loss: 0.0222
# Epoch 90/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0334
# Epoch 90: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 149ms/step - loss: 0.0334 - val_loss: 0.0221
# Epoch 91/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0333
# Epoch 91: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0333 - val_loss: 0.0222
# Epoch 92/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0332
# Epoch 92: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0332 - val_loss: 0.0217
# Epoch 93/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0324
# Epoch 93: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0324 - val_loss: 0.0216
# Epoch 94/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0328
# Epoch 94: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0328 - val_loss: 0.0215
# Epoch 95/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0325
# Epoch 95: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0325 - val_loss: 0.0219
# Epoch 96/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0324
# Epoch 96: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0324 - val_loss: 0.0220
# Epoch 97/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0324
# Epoch 97: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0324 - val_loss: 0.0218
# Epoch 98/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0321
# Epoch 98: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0321 - val_loss: 0.0210
# Epoch 99/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0322
# Epoch 99: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0322 - val_loss: 0.0213
# Epoch 100/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0325
# Epoch 100: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0325 - val_loss: 0.0214
# Epoch 101/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0326
# Epoch 101: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0326 - val_loss: 0.0214
# Epoch 102/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0319
# Epoch 102: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0319 - val_loss: 0.0212
# Epoch 103/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0308
# Epoch 103: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0308 - val_loss: 0.0211
# Epoch 104/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0317
# Epoch 104: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0317 - val_loss: 0.0215
# Epoch 105/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0320
# Epoch 105: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0320 - val_loss: 0.0209
# Epoch 106/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0318
# Epoch 106: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0318 - val_loss: 0.0207
# Epoch 107/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0316
# Epoch 107: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0316 - val_loss: 0.0211
# Epoch 108/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0311
# Epoch 108: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0311 - val_loss: 0.0204
# Epoch 109/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0318
# Epoch 109: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0318 - val_loss: 0.0209
# Epoch 110/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0310
# Epoch 110: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0310 - val_loss: 0.0208
# Epoch 111/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0314
# Epoch 111: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0314 - val_loss: 0.0228
# Epoch 112/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0317
# Epoch 112: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0317 - val_loss: 0.0208
# Epoch 113/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0306
# Epoch 113: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0306 - val_loss: 0.0208
# Epoch 114/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0308
# Epoch 114: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0308 - val_loss: 0.0217
# Epoch 115/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0310
# Epoch 115: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0310 - val_loss: 0.0212
# Epoch 116/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0307
# Epoch 116: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0307 - val_loss: 0.0206
# Epoch 117/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0311
# Epoch 117: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0311 - val_loss: 0.0218
# Epoch 118/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0306
# Epoch 118: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0306 - val_loss: 0.0227
# Epoch 119/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0314
# Epoch 119: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0314 - val_loss: 0.0223
# Epoch 120/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0308
# Epoch 120: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0308 - val_loss: 0.0209
# Epoch 121/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0302
# Epoch 121: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0302 - val_loss: 0.0203
# Epoch 122/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0303
# Epoch 122: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0303 - val_loss: 0.0201
# Epoch 123/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0302
# Epoch 123: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0302 - val_loss: 0.0203
# Epoch 124/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0303
# Epoch 124: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0303 - val_loss: 0.0205
# Epoch 125/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0305
# Epoch 125: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 146ms/step - loss: 0.0305 - val_loss: 0.0211
# Epoch 126/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0308
# Epoch 126: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0308 - val_loss: 0.0205
# Epoch 127/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0299
# Epoch 127: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0299 - val_loss: 0.0206
# Epoch 128/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0298
# Epoch 128: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0298 - val_loss: 0.0200
# Epoch 129/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0303
# Epoch 129: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0303 - val_loss: 0.0202
# Epoch 130/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0296
# Epoch 130: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0296 - val_loss: 0.0200
# Epoch 131/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0296
# Epoch 131: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0296 - val_loss: 0.0199
# Epoch 132/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0296
# Epoch 132: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0296 - val_loss: 0.0204
# Epoch 133/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0297
# Epoch 133: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0297 - val_loss: 0.0201
# Epoch 134/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0294
# Epoch 134: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0294 - val_loss: 0.0215
# Epoch 135/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0294
# Epoch 135: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0294 - val_loss: 0.0204
# Epoch 136/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0295
# Epoch 136: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0295 - val_loss: 0.0199
# Epoch 137/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0296
# Epoch 137: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 144ms/step - loss: 0.0296 - val_loss: 0.0218
# Epoch 138/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0297
# Epoch 138: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0297 - val_loss: 0.0198
# Epoch 139/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0291
# Epoch 139: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0291 - val_loss: 0.0197
# Epoch 140/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0286
# Epoch 140: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0286 - val_loss: 0.0197
# Epoch 141/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0295
# Epoch 141: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0295 - val_loss: 0.0195
# Epoch 142/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0292
# Epoch 142: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0292 - val_loss: 0.0198
# Epoch 143/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0289
# Epoch 143: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0289 - val_loss: 0.0194
# Epoch 144/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0287
# Epoch 144: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0287 - val_loss: 0.0203
# Epoch 145/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0293
# Epoch 145: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 145ms/step - loss: 0.0293 - val_loss: 0.0200
# Epoch 146/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0288
# Epoch 146: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0288 - val_loss: 0.0198
# Epoch 147/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0288
# Epoch 147: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0288 - val_loss: 0.0206
# Epoch 148/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0292
# Epoch 148: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 152ms/step - loss: 0.0292 - val_loss: 0.0203
# Epoch 149/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0297
# Epoch 149: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 158ms/step - loss: 0.0297 - val_loss: 0.0205
# Epoch 150/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0293
# Epoch 150: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 161ms/step - loss: 0.0293 - val_loss: 0.0206
# Epoch 151/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0288
# Epoch 151: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 149ms/step - loss: 0.0288 - val_loss: 0.0203
# Epoch 152/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0291
# Epoch 152: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 163ms/step - loss: 0.0291 - val_loss: 0.0193
# Epoch 153/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0283
# Epoch 153: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 153ms/step - loss: 0.0283 - val_loss: 0.0201
# Epoch 154/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0283
# Epoch 154: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 151ms/step - loss: 0.0283 - val_loss: 0.0195
# Epoch 155/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0283
# Epoch 155: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0283 - val_loss: 0.0198
# Epoch 156/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0286
# Epoch 156: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0286 - val_loss: 0.0198
# Epoch 157/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0286
# Epoch 157: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0286 - val_loss: 0.0192
# Epoch 158/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0282
# Epoch 158: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0282 - val_loss: 0.0197
# Epoch 159/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0287
# Epoch 159: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0287 - val_loss: 0.0194
# Epoch 160/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0281
# Epoch 160: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0281 - val_loss: 0.0196
# Epoch 161/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0279
# Epoch 161: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0279 - val_loss: 0.0195
# Epoch 162/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0280
# Epoch 162: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0280 - val_loss: 0.0202
# Epoch 163/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0286
# Epoch 163: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0286 - val_loss: 0.0192
# Epoch 164/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0279
# Epoch 164: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0279 - val_loss: 0.0200
# Epoch 165/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0280
# Epoch 165: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0280 - val_loss: 0.0188
# Epoch 166/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0275
# Epoch 166: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0275 - val_loss: 0.0192
# Epoch 167/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0277
# Epoch 167: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0277 - val_loss: 0.0189
# Epoch 168/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0282
# Epoch 168: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0282 - val_loss: 0.0186
# Epoch 169/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0280
# Epoch 169: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 146ms/step - loss: 0.0280 - val_loss: 0.0193
# Epoch 170/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0274
# Epoch 170: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0274 - val_loss: 0.0193
# Epoch 171/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0276
# Epoch 171: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0276 - val_loss: 0.0190
# Epoch 172/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0269
# Epoch 172: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0269 - val_loss: 0.0187
# Epoch 173/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0273
# Epoch 173: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0273 - val_loss: 0.0190
# Epoch 174/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0278
# Epoch 174: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0278 - val_loss: 0.0189
# Epoch 175/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0268
# Epoch 175: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0268 - val_loss: 0.0189
# Epoch 176/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0277
# Epoch 176: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0277 - val_loss: 0.0190
# Epoch 177/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0273
# Epoch 177: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 144ms/step - loss: 0.0273 - val_loss: 0.0188
# Epoch 178/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0273
# Epoch 178: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0273 - val_loss: 0.0198
# Epoch 179/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0272
# Epoch 179: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0272 - val_loss: 0.0185
# Epoch 180/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0272
# Epoch 180: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0272 - val_loss: 0.0190
# Epoch 181/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0275
# Epoch 181: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0275 - val_loss: 0.0187
# Epoch 182/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0272
# Epoch 182: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0272 - val_loss: 0.0184
# Epoch 183/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0271
# Epoch 183: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0271 - val_loss: 0.0189
# Epoch 184/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0267
# Epoch 184: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0267 - val_loss: 0.0193
# Epoch 185/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0273
# Epoch 185: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0273 - val_loss: 0.0184
# Epoch 186/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0273
# Epoch 186: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0273 - val_loss: 0.0184
# Epoch 187/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0274
# Epoch 187: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0274 - val_loss: 0.0184
# Epoch 188/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0262
# Epoch 188: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0262 - val_loss: 0.0188
# Epoch 189/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0269
# Epoch 189: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0269 - val_loss: 0.0187
# Epoch 190/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0269
# Epoch 190: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0269 - val_loss: 0.0183
# Epoch 191/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0269
# Epoch 191: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0269 - val_loss: 0.0188
# Epoch 192/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0266
# Epoch 192: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0266 - val_loss: 0.0184
# Epoch 193/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0269
# Epoch 193: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0269 - val_loss: 0.0210
# Epoch 194/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0271
# Epoch 194: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0271 - val_loss: 0.0185
# Epoch 195/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0269
# Epoch 195: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0269 - val_loss: 0.0194
# Epoch 196/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0274
# Epoch 196: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0274 - val_loss: 0.0190
# Epoch 197/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0268
# Epoch 197: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0268 - val_loss: 0.0179
# Epoch 198/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0274
# Epoch 198: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0274 - val_loss: 0.0217
# Epoch 199/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0271
# Epoch 199: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0271 - val_loss: 0.0181
# Epoch 200/200
# 13/13 [==============================] - ETA: 0s - loss: 0.0265
# Epoch 200: saving model to rwpinn_model.h5
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0265 - val_loss: 0.0182

# %%
# load the saved model
rw_pinn.load_weights('rwpinn_model.h5')

# %%
# Testing and evaluating the model
Batch_size=128
preds = rw_pinn.evaluate(X_test_final, Y_test, batch_size=Batch_size, verbose=0, sample_weight=None)
print()
print ("Loss = " + str(preds))
# Out:
# Loss = 0.018079234287142754

# %%
# Plotting the learning curve 
plt.plot(history.history['loss']/np.max(history.history['loss']))
plt.plot(history.history['val_loss']/np.max(history.history['val_loss']))

#plt.title('Learning curve')
plt.ylabel('Normalized Loss')
plt.xlabel('Epochs')
plt.legend(['Training loss', 'Validation loss'], loc='upper right')

# %%
## Only the Encoder part
rw_pinn_encoder = Model(inputs=input_final, outputs=encoded)

# %%
encoder_output_trainset = rw_pinn_encoder.predict(X_train_final)
phi_trainset_pred=((encoder_output_trainset+1)/2) * (phi_max - phi_min) + phi_min

# %%
encoder_output_testset = rw_pinn_encoder.predict(X_test_final)
phi_testset_pred=((encoder_output_testset+1)/2) * (phi_max - phi_min) + phi_min

# %%
phi_trainset_true=Y_train[:,246:246+199] * (phi_max - phi_min) + phi_min
phi_testset_true=Y_test[:,246:246+199] * (phi_max - phi_min) + phi_min

# %%
phi_train_error=mean_squared_error(phi_trainset_true,phi_trainset_pred)
phi_test_error=mean_squared_error(phi_testset_true,phi_testset_pred)

print('Porosity Train error:',phi_train_error)
print('Porosity Test error:',phi_test_error)
# Out:
# Porosity Train error: 0.002564264542880688
# Porosity Test error: 0.0026032504942223814

# %%
sample_number=400

plt.plot(phi_trainset_true[sample_number, :], depth, color = "black",label='true')
plt.plot(phi_trainset_pred[sample_number, :], depth,label='predicted')
plt.xlabel("Porosity [V/V]")
plt.ylabel("Depth [meters]")
plt.legend()
plt.gca().invert_yaxis()

# %%
## Only the Decoder part
rw_pinn_decoder = Model(inputs=encoded, outputs=seis_for_final)

# %%
decoder_output_trainset = rw_pinn_decoder.predict(encoder_output_trainset)
seis_output_trainset=decoder_output_trainset[:,0:246]

decoder_output_testset = rw_pinn_decoder.predict(encoder_output_testset)
seis_output_testset=decoder_output_testset[:,0:246]

# %%
plt.plot(np.squeeze(X_train_final[sample_number,:,:]),time_upscaled, color = "black",label='true')
plt.plot(seis_output_trainset[sample_number,:],time_upscaled,label='predicted')
plt.gca().invert_yaxis()
plt.legend()
plt.ylabel('Time')
# Out:
# Text(0, 0.5, 'Time')

# %%
encoder_output_set = rw_pinn_encoder.predict(np.expand_dims(np.expand_dims(seis_normalized, axis=1),axis=3))
phi_set_pred=((encoder_output_set+1)/2) * (phi_max - phi_min) + phi_min

decoder_output_set = rw_pinn_decoder.predict(encoder_output_set)
seis_output_set=decoder_output_set[:,0:246]

# %%
phi_error=np.sqrt(mean_squared_error(phi_true,phi_set_pred))

print('Porosity RMS error:',phi_error)
# Out:
# Porosity RMS error: 0.05071549795382995

# %%
phi_train_error=np.sqrt(mean_squared_error(phi_trainset_true,phi_trainset_pred))
phi_test_error=np.sqrt(mean_squared_error(phi_testset_true,phi_testset_pred))

print('Porosity Trainset RMS error:',phi_train_error)
print('Porosity Testset RMS error:',phi_test_error)
# Out:
# Porosity Trainset RMS error: 0.050638567741205794
# Porosity Testset RMS error: 0.051022058898307715

# %%
seis_error=np.sqrt(mean_squared_error(seis,seis_output_set*(np.max(seis)-np.min(seis))+ np.min(seis)))
seis_error_train=np.sqrt(mean_squared_error(np.squeeze(X_train_final)*(np.max(seis)-np.min(seis))+ np.min(seis),seis_output_trainset*(np.max(seis)-np.min(seis))+ np.min(seis)))
seis_error_test=np.sqrt(mean_squared_error(np.squeeze(X_test_final)*(np.max(seis)-np.min(seis))+ np.min(seis),seis_output_testset*(np.max(seis)-np.min(seis))+ np.min(seis)))

print('Seismic RMS error:',seis_error)
print('Seismic Train RMS error:',seis_error_train)
print('Seismic Test RMS error:',seis_error_test)
# Out:
# Seismic RMS error: 0.004309075142039134
# Seismic Train RMS error: 0.004118780273629881
# Seismic Test RMS error: 0.004998323663872068

# %%
plt.figure()
fig, axs = plt.subplots(1, 4, sharey=True)
axs[0].plot(np.squeeze(X_train_final[34,:,:]),time_upscaled,'k')
axs[0].set_yticks([0,0.05,0.1,0.15])
axs[0].set_xticks([0,0.5,1])
axs[0].set_xticklabels(('0','0.5','1'))
axs[0].set_title('Train-set')

axs[1].plot(np.squeeze(X_train_final[64,:,:]),time_upscaled,'k')
axs[1].set_xticks([0,0.5,1])
axs[1].set_xticklabels(('0','0.5','1'))
axs[1].set_title('Train-set')

axs[2].plot(np.squeeze(X_test_final[21,:,:]),time_upscaled,'k')
axs[2].set_xticks([0,0.5,1])
axs[2].set_xticklabels(('0','0.5','1'))
axs[2].set_title('Test-set')

axs[3].plot(np.squeeze(X_test_final[26,:,:]),time_upscaled,'k')
axs[3].set_xticks([0,0.5,1])
axs[3].set_xticklabels(('0','0.5','1'))
axs[3].set_title('Test-set')

fig.supxlabel('Normalized amplitude')
fig.supylabel('Time(s)')

plt.gca().invert_yaxis()

# %%
plt.figure()
fig, axs = plt.subplots(1, 4, sharey=True)
axs[0].plot(phi_trainset_true[34, :], depth,'k')
axs[0].set_yticks([0,50,100,150,200])
axs[0].set_xticks([0.2,0.3])
axs[0].set_title('Train-set')

axs[1].plot(phi_trainset_true[64, :], depth,'k')
axs[1].set_xticks([0.2,0.3])
axs[1].set_title('Train-set')

axs[2].plot(phi_testset_true[21, :], depth,'k')
axs[2].set_xticks([0.2,0.3])
axs[2].set_title('Test-set')

axs[3].plot(phi_testset_true[26, :], depth,'k')
axs[3].set_xticks([0.2,0.3])
axs[3].set_title('Test-set')

fig.supxlabel('Porosity(V/V)')
fig.supylabel('Depth(m)')

plt.gca().invert_yaxis()

# %%
plt.figure()
fig, axs = plt.subplots(1, 4, sharey=True)
axs[0].plot(np.squeeze(X_train_final[34,:,:]),time_upscaled,'k',linewidth=2,label='True')
axs[0].plot(seis_output_trainset[34,:],time_upscaled,'o',alpha=0.2,label='Predicted')
axs[0].set_yticks([0,0.05,0.1,0.15])
axs[0].set_xticks([0,0.5,1])
axs[0].set_xticklabels(('0','0.5','1'))
axs[0].set_title('Train-set')

axs[1].plot(np.squeeze(X_train_final[64,:,:]),time_upscaled,'k',linewidth=2)
axs[1].plot(seis_output_trainset[64,:],time_upscaled,'o',alpha=0.2)
axs[1].set_xticks([0,0.5,1])
axs[1].set_xticklabels(('0','0.5','1'))
axs[1].set_title('Train-set')

axs[2].plot(np.squeeze(X_test_final[21,:,:]),time_upscaled,'k',linewidth=2)
axs[2].plot(seis_output_testset[21,:],time_upscaled,'o',alpha=0.2)
axs[2].set_xticks([0,0.5,1])
axs[2].set_xticklabels(('0','0.5','1'))
axs[2].set_title('Test-set')

axs[3].plot(np.squeeze(X_test_final[26,:,:]),time_upscaled,'k',linewidth=2)
axs[3].plot(seis_output_testset[26,:],time_upscaled,'o',alpha=0.2)
axs[3].set_xticks([0,0.5,1])
axs[3].set_xticklabels(('0','0.5','1'))
axs[3].set_title('Test-set')

fig.supxlabel('Normalized amplitude')
fig.supylabel('Time(s)')
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower left')

plt.gca().invert_yaxis()

# %%
plt.figure()
fig, axs = plt.subplots(1, 4, sharey=True)
axs[0].plot(phi_trainset_true[34, :], depth,'k',label='True')
axs[0].plot(phi_trainset_pred[34, :], depth,label='Predicted')
axs[0].set_yticks([0,50,100,150,200])
axs[0].set_xticks([0.2,0.3])
axs[0].set_title('Train-set')

axs[1].plot(phi_trainset_true[64, :], depth,'k')
axs[1].plot(phi_trainset_pred[64, :], depth)
axs[1].set_xticks([0.2,0.3])
axs[1].set_title('Train-set')

axs[2].plot(phi_testset_true[21, :], depth,'k')
axs[2].plot(phi_testset_pred[21, :], depth)
axs[2].set_xticks([0.2,0.3])
axs[2].set_title('Test-set')

axs[3].plot(phi_testset_true[26, :], depth,'k')
axs[3].plot(phi_testset_pred[26, :], depth)
axs[3].set_xticks([0.2,0.3])
axs[3].set_title('Test-set')

fig.supxlabel('Porosity(V/V)')
fig.supylabel('Depth(m)')
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower left')

plt.gca().invert_yaxis()
